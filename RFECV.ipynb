# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DataSet_DataStart-Contest/X.csv")
Y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DataSet_DataStart-Contest/Y.csv")

# %%
X = X.drop(columns = 'Unnamed: 0')

# %%
X = X.set_index(['CCM_TEC/ISG', 'SLAB_ID', 'ZOB_ID' ])

# %%
Y = Y.drop(columns = 'Unnamed: 0')

# %%
Y = Y.set_index(['CCM_TEC/ISG', 'SLAB_ID'])

# %%
X.head(1)
# Out:
#                             LF(4)  ...  LF_TEC/CHANGE/CASI-CAFE
# CCM_TEC/ISG SLAB_ID ZOB_ID         ...
# 1821.0      635511  635417      0  ...                      0.0
#
# [1 rows x 242 columns]

# %%
Y.head(1)
# Out:
#                      UNDEFECTED_SLAB  ...  TEC/DEFECT/998
# CCM_TEC/ISG SLAB_ID                   ...
# 1821.0      635511                 0  ...               0
#
# [1 rows x 116 columns]

# %% [markdown]
# TEST 1

# %%
YY = Y['TEC/DEFECT/900']

# %%
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFECV
from sklearn.svm import SVC

estimator = SVC(kernel="linear")
selector = RFECV(estimator, step=1, cv=5)
selector = selector.fit(X, YY)
selector.support_
selector.ranking_
